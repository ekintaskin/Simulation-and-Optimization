# %%
from simulation import Simulation
from time import time
from stats import Stats
import matplotlib.pyplot as plt
import numpy as np

def bootstrap_mse_convergence(simulation, stat_func=np.mean, max_bootstrap=1000, step=10):
    print("Running single simulation for bootstrap convergence analysis...")
    requests = simulation.run()
    stats = Stats(requests)
    data = stats.get_waiting_time()

    true_stat = stat_func(data)
    sample_sizes = range(step, max_bootstrap + 1, step)
    
    bootstrap_estimates = []
    mse_progression = []
    for i in range(max_bootstrap):
        bootstrap_estimates.append(stat_func(np.random.choice(data, size=len(data), replace=True)))
        
        if (i + 1) % step == 0 and i > 1:
            mse_progression.append(np.mean((np.array(bootstrap_estimates) - true_stat) ** 2))

    # Plot MSE vs number of bootstrap samples
    plt.figure(figsize=(8, 6))
    plt.plot(sample_sizes, mse_progression, marker='o', color='darkorange')
    plt.axhline(0.5, color='red', linestyle='--', label='Target MSE = 0.5')
    plt.title('Bootstrap MSE Convergence for Mean Waiting Time')
    plt.xlabel('Number of Bootstrap Samples')
    plt.ylabel('MSE')
    plt.grid(True)
    plt.legend()
    plt.show()
    
    plt.figure()
    plt.plot(np.arange(0, 500, 25) + 1, 1.96*np.sqrt(mse_progression[-1]/(np.arange(0, 500, 25)+1)), marker='o', color='darkorange')
    plt.axhline(0.5, color='red', linestyle='--', label='Target precision = 0.5')
    plt.title('95% CI half-width against # simulations')
    plt.xlabel('Number of simulations')
    plt.ylabel('95% CI half-width')
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
def main():
    # Parameters
    num_runs = 100  # Number of simulation runs
    threshold = 60  # Acceptable max waiting time threshold in seconds
    print_results = True

    # Initialize lists to store statistics
    max_waiting_times = []
    mean_waiting_times = []
    var_waiting_times = []
    median_waiting_times = []
    waiting_time_percentiles = []
    bootstrap_mse_over_runs = []
    bootstrap_mean_waiting_times = []
    ci_lows = []
    ci_highs = []
    threshold_violations = []

    # Initialize run time
    run_start_time = time()

    # Simulation class
    simulation = Simulation()

    bootstrap_mse_convergence(simulation, stat_func=np.mean, max_bootstrap=10000, step=10)

    for i in range(num_runs):
        if print_results:
            print(f"Run {i + 1}")

        # Run simulation
        requests = simulation.run()

        # Initialize statistics
        stats = Stats(requests)
        waiting_time = stats.get_waiting_time()

        # Calculate statistics
        max_waiting_time = np.max(waiting_time)
        mean_waiting_time = np.mean(waiting_time)
        var_waiting_time = np.var(waiting_time)
        median_waiting_time = np.median(waiting_time)
        waiting_time_percentile = np.percentile(waiting_time, [50, 90, 95, 99])

        max_waiting_times.append(max_waiting_time)
        mean_waiting_times.append(mean_waiting_time)
        var_waiting_times.append(var_waiting_time)
        median_waiting_times.append(median_waiting_time)
        waiting_time_percentiles.append(waiting_time_percentile)

        # Bootstrap for mean and MSE
        true_mean, mse, bootstrap_samples = stats.mse_bootstrap(np.mean, num_bootstrap=100)
        bootstrap_mse_over_runs.append(mse)
        bootstrap_mean_waiting_times.append(np.mean(bootstrap_samples))

        # Optional: Bootstrap CI for the mean
        ci_low, ci_high = np.percentile(bootstrap_samples, [2.5, 97.5])
        ci_lows.append(ci_low)
        ci_highs.append(ci_high)

        # Print basic statistics
        if print_results:
            print(f"Mean, Median, Max and Variance of Waiting Time: {mean_waiting_time:.2f} s, {median_waiting_time:.2f} s, {max_waiting_time:.2f} s, {var_waiting_time:.2f} s")
            print(f"Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: {waiting_time_percentile}")
            print(f"MSE of Bootstrap Mean Waiting Time: {mse:.4f}")
            print(f"95% CI for Mean Waiting Time (bootstrap): [{ci_low:.2f}, {ci_high:.2f}]")

        # Customers above threshold
        count_above, pct_above = stats.num_customers_above_threshold(threshold)
        threshold_violations.append(count_above)
        if print_results:
            print(f"Customers above {threshold:.2f} s: {count_above}, In percentage: {pct_above:.2f}%\n")

    # Plotting
    def make_hist(data, title, xlabel):
        plt.figure(figsize=(8, 6))
        plt.hist(data, bins=20, color='skyblue', edgecolor='black')
        plt.title(title)
        plt.xlabel(xlabel)
        plt.ylabel('Frequency')
        plt.grid(True)
        plt.show()

    make_hist(max_waiting_times, 'Histogram of Maximum Waiting Times', 'Maximum Waiting Time (s)')
    make_hist(mean_waiting_times, 'Histogram of Mean Waiting Times', 'Mean Waiting Time (s)')
    make_hist(median_waiting_times, 'Histogram of Median Waiting Times', 'Median Waiting Time (s)')
    make_hist(var_waiting_times, 'Histogram of Waiting Time Variance', 'Waiting Time Variance (s)')
    make_hist(threshold_violations, 'Histogram of Customers Exceeding Threshold', 'Customers Above Threshold')

    # Plot MSE over runs
    plt.figure(figsize=(16, 6))
    plt.plot(range(1, num_runs + 1), bootstrap_mse_over_runs, marker='o', color='darkred')
    plt.title('Bootstrap MSE of Mean Waiting Time Over Simulation Runs')
    plt.xlabel('Simulation Run')
    plt.ylabel('Bootstrap MSE')
    plt.grid(True)
    plt.show()

    # Optional: CI band for mean waiting time
    plt.figure(figsize=(16, 6))
    plt.plot(mean_waiting_times, label="Mean Waiting Time", color='blue')
    plt.fill_between(range(num_runs), ci_lows, ci_highs, color='lightblue', alpha=0.5, label="95% Bootstrap CI")
    plt.title('Mean Waiting Time with 95% Bootstrap Confidence Interval')
    plt.xlabel('Simulation Run')
    plt.ylabel('Waiting Time (s)')
    plt.legend()
    plt.grid(True)
    plt.show()

    run_end_time = time()
    print(f"Elapsed time: {run_end_time - run_start_time:.2f} seconds")


if __name__ == "__main__":
    main()
# Out:
# Running single simulation for bootstrap convergence analysis...
# Run 1
# Mean, Median, Max and Variance of Waiting Time: 106.16 s, 12.87 s, 437.54 s, 19232.00 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 12.86580006 349.66094108 395.88976624 428.40978875]
# MSE of Bootstrap Mean Waiting Time: 2.0636
# 95% CI for Mean Waiting Time (bootstrap): [103.06, 108.93]
# Customers above 60.00 s: 3453, In percentage: 38.11%
#
# Run 2
# Mean, Median, Max and Variance of Waiting Time: 113.92 s, 13.41 s, 478.81 s, 21777.83 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.40989038 372.60868553 421.70044294 462.9313314 ]
# MSE of Bootstrap Mean Waiting Time: 2.2620
# 95% CI for Mean Waiting Time (bootstrap): [111.26, 116.79]
# Customers above 60.00 s: 3617, In percentage: 39.76%
#
# Run 3
# Mean, Median, Max and Variance of Waiting Time: 95.13 s, 13.40 s, 401.14 s, 15518.01 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.39896559 316.81627988 360.88293868 389.62553909]
# MSE of Bootstrap Mean Waiting Time: 1.4862
# 95% CI for Mean Waiting Time (bootstrap): [93.16, 97.37]
# Customers above 60.00 s: 3354, In percentage: 37.14%
#
# Run 4
# Mean, Median, Max and Variance of Waiting Time: 106.18 s, 13.51 s, 431.31 s, 18567.52 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.50541897 344.95821308 396.5481936  423.27982288]
# MSE of Bootstrap Mean Waiting Time: 1.6427
# 95% CI for Mean Waiting Time (bootstrap): [103.70, 108.73]
# Customers above 60.00 s: 3516, In percentage: 39.47%
#
# Run 5
# Mean, Median, Max and Variance of Waiting Time: 92.20 s, 12.93 s, 417.12 s, 15264.22 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 12.92859868 305.5259011  363.34367849 401.56871091]
# MSE of Bootstrap Mean Waiting Time: 1.4954
# 95% CI for Mean Waiting Time (bootstrap): [90.27, 94.71]
# Customers above 60.00 s: 3270, In percentage: 35.90%
#
# Run 6
# Mean, Median, Max and Variance of Waiting Time: 109.32 s, 13.11 s, 438.96 s, 20049.67 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.11194289 357.42372446 391.73734881 417.41933377]
# MSE of Bootstrap Mean Waiting Time: 2.2666
# 95% CI for Mean Waiting Time (bootstrap): [106.01, 111.91]
# Customers above 60.00 s: 3479, In percentage: 38.40%
#
# Run 7
# Mean, Median, Max and Variance of Waiting Time: 93.72 s, 12.99 s, 438.13 s, 16312.88 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 12.98972672 319.42130721 358.93248612 414.79639436]
# MSE of Bootstrap Mean Waiting Time: 1.5581
# 95% CI for Mean Waiting Time (bootstrap): [91.15, 95.70]
# Customers above 60.00 s: 3194, In percentage: 35.31%
#
# Run 8
# Mean, Median, Max and Variance of Waiting Time: 107.56 s, 13.13 s, 457.09 s, 20084.33 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.12619608 350.40855147 407.24409535 450.08477162]
# MSE of Bootstrap Mean Waiting Time: 2.2369
# 95% CI for Mean Waiting Time (bootstrap): [104.85, 110.01]
# Customers above 60.00 s: 3505, In percentage: 38.15%
#
# Run 9
# Mean, Median, Max and Variance of Waiting Time: 103.23 s, 13.44 s, 460.94 s, 19152.42 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.44429406 341.63948367 410.63217185 444.89990164]
# MSE of Bootstrap Mean Waiting Time: 2.2780
# 95% CI for Mean Waiting Time (bootstrap): [100.22, 106.26]
# Customers above 60.00 s: 3400, In percentage: 36.71%
#
# Run 10
# Mean, Median, Max and Variance of Waiting Time: 109.14 s, 14.98 s, 460.23 s, 20052.59 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.97931789 367.20395409 404.53082423 447.03946239]
# MSE of Bootstrap Mean Waiting Time: 1.6049
# 95% CI for Mean Waiting Time (bootstrap): [106.94, 111.43]
# Customers above 60.00 s: 3622, In percentage: 38.87%
#
# Run 11
# Mean, Median, Max and Variance of Waiting Time: 79.69 s, 12.87 s, 393.45 s, 12187.48 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 12.86623943 278.69410675 330.48710875 379.89313195]
# MSE of Bootstrap Mean Waiting Time: 1.3545
# 95% CI for Mean Waiting Time (bootstrap): [77.22, 81.86]
# Customers above 60.00 s: 3114, In percentage: 34.44%
#
# Run 12
# Mean, Median, Max and Variance of Waiting Time: 75.98 s, 13.98 s, 369.39 s, 10787.26 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.98428493 251.83090745 313.80473499 351.95836049]
# MSE of Bootstrap Mean Waiting Time: 1.0697
# 95% CI for Mean Waiting Time (bootstrap): [74.25, 77.77]
# Customers above 60.00 s: 2906, In percentage: 32.29%
#
# Run 13
# Mean, Median, Max and Variance of Waiting Time: 132.78 s, 14.99 s, 524.85 s, 29456.72 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.99166313 434.31225219 480.12997791 513.59156522]
# MSE of Bootstrap Mean Waiting Time: 2.6925
# 95% CI for Mean Waiting Time (bootstrap): [130.00, 136.11]
# Customers above 60.00 s: 3718, In percentage: 40.61%
#
# Run 14
# Mean, Median, Max and Variance of Waiting Time: 92.09 s, 13.67 s, 432.44 s, 15387.68 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.66984388 300.4916489  380.87737402 418.91103427]
# MSE of Bootstrap Mean Waiting Time: 1.6161
# 95% CI for Mean Waiting Time (bootstrap): [89.58, 94.63]
# Customers above 60.00 s: 3309, In percentage: 36.32%
#
# Run 15
# Mean, Median, Max and Variance of Waiting Time: 99.71 s, 13.54 s, 455.43 s, 18013.25 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.54118608 333.10822092 397.39976716 445.20020481]
# MSE of Bootstrap Mean Waiting Time: 2.1480
# 95% CI for Mean Waiting Time (bootstrap): [96.45, 102.08]
# Customers above 60.00 s: 3400, In percentage: 37.44%
#
# Run 16
# Mean, Median, Max and Variance of Waiting Time: 112.18 s, 13.16 s, 487.17 s, 22518.94 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.15842889 376.61011797 428.15895633 476.91306398]
# MSE of Bootstrap Mean Waiting Time: 2.9437
# 95% CI for Mean Waiting Time (bootstrap): [109.09, 115.70]
# Customers above 60.00 s: 3441, In percentage: 37.78%
#
# Run 17
# Mean, Median, Max and Variance of Waiting Time: 104.00 s, 13.56 s, 456.13 s, 19380.78 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.55735388 353.70838024 399.20881065 441.01802881]
# MSE of Bootstrap Mean Waiting Time: 1.8603
# 95% CI for Mean Waiting Time (bootstrap): [101.78, 106.68]
# Customers above 60.00 s: 3358, In percentage: 37.27%
#
# Run 18
# Mean, Median, Max and Variance of Waiting Time: 104.94 s, 14.50 s, 448.42 s, 19398.86 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.5049672  353.73746226 411.30031998 441.38296708]
# MSE of Bootstrap Mean Waiting Time: 2.0144
# 95% CI for Mean Waiting Time (bootstrap): [102.32, 107.56]
# Customers above 60.00 s: 3568, In percentage: 38.25%
#
# Run 19
# Mean, Median, Max and Variance of Waiting Time: 97.78 s, 13.50 s, 427.05 s, 16612.14 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.50349886 325.90008682 376.30041636 419.05881672]
# MSE of Bootstrap Mean Waiting Time: 2.4413
# 95% CI for Mean Waiting Time (bootstrap): [95.43, 101.04]
# Customers above 60.00 s: 3484, In percentage: 38.00%
#
# Run 20
# Mean, Median, Max and Variance of Waiting Time: 101.86 s, 13.39 s, 425.85 s, 17134.41 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.39029706 328.03420872 371.76907764 410.93712742]
# MSE of Bootstrap Mean Waiting Time: 1.9388
# 95% CI for Mean Waiting Time (bootstrap): [98.97, 104.41]
# Customers above 60.00 s: 3479, In percentage: 38.60%
#
# Run 21
# Mean, Median, Max and Variance of Waiting Time: 94.12 s, 12.71 s, 422.03 s, 15540.07 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 12.70730302 318.26200592 349.63447159 407.89258804]
# MSE of Bootstrap Mean Waiting Time: 1.7679
# 95% CI for Mean Waiting Time (bootstrap): [91.99, 96.78]
# Customers above 60.00 s: 3262, In percentage: 36.57%
#
# Run 22
# Mean, Median, Max and Variance of Waiting Time: 103.50 s, 14.16 s, 453.56 s, 18376.60 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.16265994 326.49244287 398.98994674 439.94560174]
# MSE of Bootstrap Mean Waiting Time: 2.5797
# 95% CI for Mean Waiting Time (bootstrap): [100.42, 106.58]
# Customers above 60.00 s: 3531, In percentage: 38.61%
#
# Run 23
# Mean, Median, Max and Variance of Waiting Time: 98.18 s, 13.88 s, 430.52 s, 16811.37 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.87976925 319.2956463  377.47886497 415.46225607]
# MSE of Bootstrap Mean Waiting Time: 1.9074
# 95% CI for Mean Waiting Time (bootstrap): [95.72, 100.74]
# Customers above 60.00 s: 3385, In percentage: 36.95%
#
# Run 24
# Mean, Median, Max and Variance of Waiting Time: 95.88 s, 13.16 s, 399.63 s, 15861.89 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.164198   327.51937223 367.10314998 386.91069623]
# MSE of Bootstrap Mean Waiting Time: 1.5843
# 95% CI for Mean Waiting Time (bootstrap): [93.45, 98.13]
# Customers above 60.00 s: 3417, In percentage: 37.76%
#
# Run 25
# Mean, Median, Max and Variance of Waiting Time: 114.64 s, 13.64 s, 510.68 s, 23835.15 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.63521162 392.01477546 449.18891146 497.65711763]
# MSE of Bootstrap Mean Waiting Time: 2.6358
# 95% CI for Mean Waiting Time (bootstrap): [110.57, 117.55]
# Customers above 60.00 s: 3539, In percentage: 38.53%
#
# Run 26
# Mean, Median, Max and Variance of Waiting Time: 96.60 s, 14.15 s, 418.18 s, 15704.83 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.15034276 314.96477405 360.23486802 403.03626314]
# MSE of Bootstrap Mean Waiting Time: 1.5927
# 95% CI for Mean Waiting Time (bootstrap): [94.11, 99.04]
# Customers above 60.00 s: 3363, In percentage: 37.14%
#
# Run 27
# Mean, Median, Max and Variance of Waiting Time: 103.27 s, 13.68 s, 490.22 s, 20403.60 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.67808853 347.46210376 425.17626474 471.3395856 ]
# MSE of Bootstrap Mean Waiting Time: 2.6196
# 95% CI for Mean Waiting Time (bootstrap): [100.60, 106.79]
# Customers above 60.00 s: 3236, In percentage: 35.44%
#
# Run 28
# Mean, Median, Max and Variance of Waiting Time: 102.30 s, 13.73 s, 465.62 s, 18279.36 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.72808579 333.50568876 399.14419749 447.61685418]
# MSE of Bootstrap Mean Waiting Time: 1.9712
# 95% CI for Mean Waiting Time (bootstrap): [99.29, 104.76]
# Customers above 60.00 s: 3454, In percentage: 37.70%
#
# Run 29
# Mean, Median, Max and Variance of Waiting Time: 106.67 s, 14.12 s, 472.53 s, 20414.97 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.11623138 359.39667429 417.09055616 463.64002977]
# MSE of Bootstrap Mean Waiting Time: 2.6764
# 95% CI for Mean Waiting Time (bootstrap): [103.55, 109.62]
# Customers above 60.00 s: 3510, In percentage: 38.34%
#
# Run 30
# Mean, Median, Max and Variance of Waiting Time: 99.40 s, 13.02 s, 442.81 s, 17315.17 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.01799613 334.48747065 381.25410092 424.53934175]
# MSE of Bootstrap Mean Waiting Time: 1.7773
# 95% CI for Mean Waiting Time (bootstrap): [96.88, 101.64]
# Customers above 60.00 s: 3522, In percentage: 38.41%
#
# Run 31
# Mean, Median, Max and Variance of Waiting Time: 123.94 s, 14.33 s, 535.99 s, 26197.97 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.32629203 416.80901779 458.90570929 521.4752363 ]
# MSE of Bootstrap Mean Waiting Time: 2.4067
# 95% CI for Mean Waiting Time (bootstrap): [120.82, 126.26]
# Customers above 60.00 s: 3660, In percentage: 39.74%
#
# Run 32
# Mean, Median, Max and Variance of Waiting Time: 106.09 s, 13.10 s, 448.69 s, 19123.23 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.10295324 347.49800831 395.29162583 437.83023775]
# MSE of Bootstrap Mean Waiting Time: 2.0392
# 95% CI for Mean Waiting Time (bootstrap): [103.12, 108.69]
# Customers above 60.00 s: 3475, In percentage: 38.44%
#
# Run 33
# Mean, Median, Max and Variance of Waiting Time: 122.47 s, 13.45 s, 502.37 s, 25622.06 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.44670126 411.58206875 456.91436501 481.87165145]
# MSE of Bootstrap Mean Waiting Time: 3.5693
# 95% CI for Mean Waiting Time (bootstrap): [119.14, 126.39]
# Customers above 60.00 s: 3614, In percentage: 39.59%
#
# Run 34
# Mean, Median, Max and Variance of Waiting Time: 86.23 s, 12.62 s, 383.94 s, 12542.11 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 12.61503719 276.86020344 325.22213472 364.04087802]
# MSE of Bootstrap Mean Waiting Time: 1.0269
# 95% CI for Mean Waiting Time (bootstrap): [84.49, 88.42]
# Customers above 60.00 s: 3255, In percentage: 36.15%
#
# Run 35
# Mean, Median, Max and Variance of Waiting Time: 94.60 s, 13.82 s, 423.48 s, 15707.08 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.81986496 316.68436305 368.09448637 413.23636014]
# MSE of Bootstrap Mean Waiting Time: 1.9776
# 95% CI for Mean Waiting Time (bootstrap): [91.93, 97.01]
# Customers above 60.00 s: 3390, In percentage: 37.13%
#
# Run 36
# Mean, Median, Max and Variance of Waiting Time: 111.39 s, 13.85 s, 477.74 s, 21896.28 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.8523053  383.60254841 426.25803378 459.79956389]
# MSE of Bootstrap Mean Waiting Time: 2.3410
# 95% CI for Mean Waiting Time (bootstrap): [108.90, 114.58]
# Customers above 60.00 s: 3542, In percentage: 38.84%
#
# Run 37
# Mean, Median, Max and Variance of Waiting Time: 122.99 s, 14.25 s, 506.30 s, 25214.89 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.24708763 400.28620973 444.30730789 497.35128967]
# MSE of Bootstrap Mean Waiting Time: 2.7764
# 95% CI for Mean Waiting Time (bootstrap): [119.52, 125.72]
# Customers above 60.00 s: 3665, In percentage: 40.26%
#
# Run 38
# Mean, Median, Max and Variance of Waiting Time: 107.16 s, 13.33 s, 457.70 s, 19952.62 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.33131927 351.84887534 407.8238004  439.70801245]
# MSE of Bootstrap Mean Waiting Time: 2.1546
# 95% CI for Mean Waiting Time (bootstrap): [104.53, 109.93]
# Customers above 60.00 s: 3489, In percentage: 38.41%
#
# Run 39
# Mean, Median, Max and Variance of Waiting Time: 92.69 s, 12.84 s, 400.01 s, 15294.54 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 12.84311837 311.12887497 351.60437103 385.03513113]
# MSE of Bootstrap Mean Waiting Time: 1.5310
# 95% CI for Mean Waiting Time (bootstrap): [90.59, 95.13]
# Customers above 60.00 s: 3244, In percentage: 36.06%
#
# Run 40
# Mean, Median, Max and Variance of Waiting Time: 99.65 s, 13.19 s, 459.44 s, 18533.57 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.1883625  344.66857873 398.51588983 443.2708744 ]
# MSE of Bootstrap Mean Waiting Time: 1.6576
# 95% CI for Mean Waiting Time (bootstrap): [97.61, 102.18]
# Customers above 60.00 s: 3393, In percentage: 36.82%
#
# Run 41
# Mean, Median, Max and Variance of Waiting Time: 95.20 s, 13.39 s, 421.39 s, 16281.99 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.38608956 317.54082754 365.37235448 410.42510807]
# MSE of Bootstrap Mean Waiting Time: 1.5827
# 95% CI for Mean Waiting Time (bootstrap): [92.93, 97.80]
# Customers above 60.00 s: 3232, In percentage: 35.45%
#
# Run 42
# Mean, Median, Max and Variance of Waiting Time: 104.02 s, 13.58 s, 458.09 s, 19016.04 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.58079966 346.32358764 393.89145336 442.17518939]
# MSE of Bootstrap Mean Waiting Time: 2.2797
# 95% CI for Mean Waiting Time (bootstrap): [101.55, 107.15]
# Customers above 60.00 s: 3380, In percentage: 37.07%
#
# Run 43
# Mean, Median, Max and Variance of Waiting Time: 91.97 s, 13.35 s, 401.28 s, 15847.10 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.34714067 330.33067421 366.56519291 392.12139931]
# MSE of Bootstrap Mean Waiting Time: 1.3799
# 95% CI for Mean Waiting Time (bootstrap): [89.45, 93.92]
# Customers above 60.00 s: 3167, In percentage: 34.72%
#
# Run 44
# Mean, Median, Max and Variance of Waiting Time: 94.74 s, 14.25 s, 426.79 s, 15596.10 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.25205184 317.59370368 367.44916833 415.07372498]
# MSE of Bootstrap Mean Waiting Time: 1.5287
# 95% CI for Mean Waiting Time (bootstrap): [92.21, 96.77]
# Customers above 60.00 s: 3452, In percentage: 37.81%
#
# Run 45
# Mean, Median, Max and Variance of Waiting Time: 86.12 s, 13.19 s, 413.17 s, 14133.39 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.19077074 306.91084953 351.47657442 401.37470599]
# MSE of Bootstrap Mean Waiting Time: 1.6638
# 95% CI for Mean Waiting Time (bootstrap): [83.81, 88.69]
# Customers above 60.00 s: 3097, In percentage: 34.42%
#
# Run 46
# Mean, Median, Max and Variance of Waiting Time: 99.07 s, 13.41 s, 446.00 s, 17898.52 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.40610833 336.77876005 393.10013186 437.51587634]
# MSE of Bootstrap Mean Waiting Time: 1.6729
# 95% CI for Mean Waiting Time (bootstrap): [96.74, 101.46]
# Customers above 60.00 s: 3362, In percentage: 36.88%
#
# Run 47
# Mean, Median, Max and Variance of Waiting Time: 85.89 s, 13.46 s, 415.87 s, 13543.57 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.46075383 291.42070339 353.38626374 403.85509831]
# MSE of Bootstrap Mean Waiting Time: 1.4139
# 95% CI for Mean Waiting Time (bootstrap): [83.30, 88.02]
# Customers above 60.00 s: 3235, In percentage: 35.37%
#
# Run 48
# Mean, Median, Max and Variance of Waiting Time: 109.61 s, 15.44 s, 477.03 s, 21745.45 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 15.43799882 375.30817277 429.58304969 469.09187371]
# MSE of Bootstrap Mean Waiting Time: 2.4979
# 95% CI for Mean Waiting Time (bootstrap): [107.13, 112.82]
# Customers above 60.00 s: 3487, In percentage: 37.63%
#
# Run 49
# Mean, Median, Max and Variance of Waiting Time: 107.17 s, 13.62 s, 489.14 s, 20576.29 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.62048863 364.4819465  416.84556475 473.24319503]
# MSE of Bootstrap Mean Waiting Time: 2.0216
# 95% CI for Mean Waiting Time (bootstrap): [104.22, 109.28]
# Customers above 60.00 s: 3553, In percentage: 39.03%
#
# Run 50
# Mean, Median, Max and Variance of Waiting Time: 105.34 s, 13.88 s, 448.86 s, 19249.73 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.87882539 352.30664995 399.38557157 431.7203097 ]
# MSE of Bootstrap Mean Waiting Time: 2.0571
# 95% CI for Mean Waiting Time (bootstrap): [103.08, 108.38]
# Customers above 60.00 s: 3472, In percentage: 38.18%
#
# Run 51
# Mean, Median, Max and Variance of Waiting Time: 103.93 s, 14.27 s, 466.09 s, 19634.63 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.26579342 344.86491644 410.29562244 457.82411229]
# MSE of Bootstrap Mean Waiting Time: 1.9981
# 95% CI for Mean Waiting Time (bootstrap): [100.97, 106.28]
# Customers above 60.00 s: 3440, In percentage: 36.94%
#
# Run 52
# Mean, Median, Max and Variance of Waiting Time: 112.68 s, 13.93 s, 508.99 s, 23406.34 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.92762576 383.05481936 462.00251471 498.70859753]
# MSE of Bootstrap Mean Waiting Time: 2.4151
# 95% CI for Mean Waiting Time (bootstrap): [109.67, 115.91]
# Customers above 60.00 s: 3549, In percentage: 38.64%
#
# Run 53
# Mean, Median, Max and Variance of Waiting Time: 94.23 s, 14.64 s, 396.42 s, 14661.91 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.63562928 306.7321606  346.24537393 382.95381431]
# MSE of Bootstrap Mean Waiting Time: 1.8513
# 95% CI for Mean Waiting Time (bootstrap): [91.54, 96.54]
# Customers above 60.00 s: 3445, In percentage: 37.77%
#
# Run 54
# Mean, Median, Max and Variance of Waiting Time: 110.26 s, 13.94 s, 504.80 s, 21920.37 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.94436705 377.01289498 429.31543134 482.82701023]
# MSE of Bootstrap Mean Waiting Time: 2.5246
# 95% CI for Mean Waiting Time (bootstrap): [108.01, 113.79]
# Customers above 60.00 s: 3510, In percentage: 38.48%
#
# Run 55
# Mean, Median, Max and Variance of Waiting Time: 108.55 s, 13.29 s, 465.10 s, 21344.91 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.2913873  378.19767755 425.49161388 453.04538146]
# MSE of Bootstrap Mean Waiting Time: 2.2806
# 95% CI for Mean Waiting Time (bootstrap): [105.71, 111.47]
# Customers above 60.00 s: 3430, In percentage: 37.90%
#
# Run 56
# Mean, Median, Max and Variance of Waiting Time: 107.42 s, 13.77 s, 438.83 s, 19727.79 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.77082883 360.23049357 409.52107691 424.15775255]
# MSE of Bootstrap Mean Waiting Time: 2.3093
# 95% CI for Mean Waiting Time (bootstrap): [104.63, 110.02]
# Customers above 60.00 s: 3371, In percentage: 37.53%
#
# Run 57
# Mean, Median, Max and Variance of Waiting Time: 82.40 s, 13.38 s, 365.94 s, 11979.78 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.38314228 285.69381179 314.7788325  350.74104643]
# MSE of Bootstrap Mean Waiting Time: 1.0987
# 95% CI for Mean Waiting Time (bootstrap): [80.63, 85.10]
# Customers above 60.00 s: 3162, In percentage: 35.20%
#
# Run 58
# Mean, Median, Max and Variance of Waiting Time: 120.68 s, 13.30 s, 505.76 s, 24896.53 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.30214669 386.9872935  455.6406323  494.42718835]
# MSE of Bootstrap Mean Waiting Time: 2.6696
# 95% CI for Mean Waiting Time (bootstrap): [117.73, 124.34]
# Customers above 60.00 s: 3622, In percentage: 39.93%
#
# Run 59
# Mean, Median, Max and Variance of Waiting Time: 95.23 s, 14.46 s, 444.14 s, 16763.21 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.45545147 322.93912583 381.44539649 431.6838439 ]
# MSE of Bootstrap Mean Waiting Time: 1.6851
# 95% CI for Mean Waiting Time (bootstrap): [93.29, 97.92]
# Customers above 60.00 s: 3333, In percentage: 36.13%
#
# Run 60
# Mean, Median, Max and Variance of Waiting Time: 94.61 s, 13.18 s, 419.11 s, 15704.04 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.17875047 324.68248514 362.88876334 400.57521207]
# MSE of Bootstrap Mean Waiting Time: 1.4424
# 95% CI for Mean Waiting Time (bootstrap): [92.41, 96.70]
# Customers above 60.00 s: 3316, In percentage: 36.82%
#
# Run 61
# Mean, Median, Max and Variance of Waiting Time: 121.55 s, 13.87 s, 502.59 s, 25120.76 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.87487522 398.05651993 454.08450291 495.27239132]
# MSE of Bootstrap Mean Waiting Time: 2.5581
# 95% CI for Mean Waiting Time (bootstrap): [118.14, 123.89]
# Customers above 60.00 s: 3687, In percentage: 40.88%
#
# Run 62
# Mean, Median, Max and Variance of Waiting Time: 104.16 s, 13.26 s, 461.34 s, 19451.48 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.26465367 354.6682835  402.75957475 445.03143031]
# MSE of Bootstrap Mean Waiting Time: 2.1377
# 95% CI for Mean Waiting Time (bootstrap): [101.50, 107.24]
# Customers above 60.00 s: 3329, In percentage: 36.64%
#
# Run 63
# Mean, Median, Max and Variance of Waiting Time: 104.87 s, 13.12 s, 454.18 s, 19227.20 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.11732978 347.63021157 396.02262876 435.57250866]
# MSE of Bootstrap Mean Waiting Time: 1.6557
# 95% CI for Mean Waiting Time (bootstrap): [102.90, 107.52]
# Customers above 60.00 s: 3377, In percentage: 37.57%
#
# Run 64
# Mean, Median, Max and Variance of Waiting Time: 101.56 s, 13.55 s, 451.51 s, 18259.30 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.55075207 352.36519053 397.66578058 435.97174783]
# MSE of Bootstrap Mean Waiting Time: 1.3284
# 95% CI for Mean Waiting Time (bootstrap): [99.35, 103.57]
# Customers above 60.00 s: 3405, In percentage: 38.21%
#
# Run 65
# Mean, Median, Max and Variance of Waiting Time: 111.83 s, 13.30 s, 488.46 s, 22139.59 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.29840583 374.99653693 429.86548771 475.18366892]
# MSE of Bootstrap Mean Waiting Time: 2.3997
# 95% CI for Mean Waiting Time (bootstrap): [108.91, 114.67]
# Customers above 60.00 s: 3550, In percentage: 38.60%
#
# Run 66
# Mean, Median, Max and Variance of Waiting Time: 92.08 s, 13.21 s, 424.39 s, 15317.22 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.21287903 314.24912647 375.55260927 413.12682719]
# MSE of Bootstrap Mean Waiting Time: 2.5033
# 95% CI for Mean Waiting Time (bootstrap): [89.05, 94.80]
# Customers above 60.00 s: 3410, In percentage: 37.39%
#
# Run 67
# Mean, Median, Max and Variance of Waiting Time: 83.10 s, 13.65 s, 374.58 s, 12361.63 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.64994869 272.94775916 325.97832054 363.69792228]
# MSE of Bootstrap Mean Waiting Time: 1.2401
# 95% CI for Mean Waiting Time (bootstrap): [80.87, 84.98]
# Customers above 60.00 s: 3143, In percentage: 34.60%
#
# Run 68
# Mean, Median, Max and Variance of Waiting Time: 105.07 s, 13.38 s, 475.25 s, 19793.31 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.3796093  356.97015183 395.04986378 458.75980422]
# MSE of Bootstrap Mean Waiting Time: 1.9908
# 95% CI for Mean Waiting Time (bootstrap): [102.17, 108.07]
# Customers above 60.00 s: 3484, In percentage: 37.95%
#
# Run 69
# Mean, Median, Max and Variance of Waiting Time: 93.77 s, 13.51 s, 450.57 s, 16489.40 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.51470005 317.32894699 375.12035955 438.882641  ]
# MSE of Bootstrap Mean Waiting Time: 1.7816
# 95% CI for Mean Waiting Time (bootstrap): [91.13, 96.09]
# Customers above 60.00 s: 3319, In percentage: 35.96%
#
# Run 70
# Mean, Median, Max and Variance of Waiting Time: 100.97 s, 13.60 s, 434.22 s, 18382.02 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.59500674 354.59466725 384.26627706 423.51682275]
# MSE of Bootstrap Mean Waiting Time: 1.9930
# 95% CI for Mean Waiting Time (bootstrap): [98.63, 103.77]
# Customers above 60.00 s: 3307, In percentage: 36.26%
#
# Run 71
# Mean, Median, Max and Variance of Waiting Time: 89.25 s, 13.54 s, 378.97 s, 13948.55 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.54048688 302.09892101 336.75324972 371.88684564]
# MSE of Bootstrap Mean Waiting Time: 1.2919
# 95% CI for Mean Waiting Time (bootstrap): [87.31, 91.23]
# Customers above 60.00 s: 3276, In percentage: 35.49%
#
# Run 72
# Mean, Median, Max and Variance of Waiting Time: 72.21 s, 12.71 s, 354.21 s, 9577.72 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 12.71072115 245.13804212 296.77617093 344.54531112]
# MSE of Bootstrap Mean Waiting Time: 0.8284
# 95% CI for Mean Waiting Time (bootstrap): [70.59, 73.71]
# Customers above 60.00 s: 3055, In percentage: 34.08%
#
# Run 73
# Mean, Median, Max and Variance of Waiting Time: 111.30 s, 13.54 s, 485.57 s, 20559.61 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.5377473  342.85950922 408.84640027 467.38342611]
# MSE of Bootstrap Mean Waiting Time: 2.7695
# 95% CI for Mean Waiting Time (bootstrap): [108.35, 114.59]
# Customers above 60.00 s: 3541, In percentage: 39.23%
#
# Run 74
# Mean, Median, Max and Variance of Waiting Time: 95.93 s, 13.39 s, 445.06 s, 17191.84 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.38720921 329.2932948  388.6657899  428.19835639]
# MSE of Bootstrap Mean Waiting Time: 1.7566
# 95% CI for Mean Waiting Time (bootstrap): [93.69, 98.73]
# Customers above 60.00 s: 3341, In percentage: 36.21%
#
# Run 75
# Mean, Median, Max and Variance of Waiting Time: 93.26 s, 13.22 s, 427.92 s, 16142.15 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.21853687 313.96350935 368.10085915 412.29743582]
# MSE of Bootstrap Mean Waiting Time: 1.6381
# 95% CI for Mean Waiting Time (bootstrap): [90.33, 95.26]
# Customers above 60.00 s: 3193, In percentage: 34.85%
#
# Run 76
# Mean, Median, Max and Variance of Waiting Time: 121.61 s, 14.38 s, 513.80 s, 25652.06 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.37915184 401.13586473 464.07304544 501.50117138]
# MSE of Bootstrap Mean Waiting Time: 2.7190
# 95% CI for Mean Waiting Time (bootstrap): [118.81, 124.99]
# Customers above 60.00 s: 3613, In percentage: 39.44%
#
# Run 77
# Mean, Median, Max and Variance of Waiting Time: 90.06 s, 13.22 s, 418.38 s, 14586.20 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.22006411 303.34454866 347.2692557  400.97783627]
# MSE of Bootstrap Mean Waiting Time: 1.5794
# 95% CI for Mean Waiting Time (bootstrap): [86.55, 91.59]
# Customers above 60.00 s: 3238, In percentage: 36.01%
#
# Run 78
# Mean, Median, Max and Variance of Waiting Time: 118.95 s, 13.67 s, 503.71 s, 24108.11 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.67329976 393.14718754 444.06123866 488.23195575]
# MSE of Bootstrap Mean Waiting Time: 2.5144
# 95% CI for Mean Waiting Time (bootstrap): [115.86, 121.82]
# Customers above 60.00 s: 3649, In percentage: 39.66%
#
# Run 79
# Mean, Median, Max and Variance of Waiting Time: 116.69 s, 14.28 s, 525.01 s, 24266.88 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.28125049 397.16913482 461.52637734 505.08713568]
# MSE of Bootstrap Mean Waiting Time: 2.5687
# 95% CI for Mean Waiting Time (bootstrap): [113.85, 119.80]
# Customers above 60.00 s: 3561, In percentage: 39.78%
#
# Run 80
# Mean, Median, Max and Variance of Waiting Time: 114.86 s, 14.43 s, 482.70 s, 22743.15 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.4324555  363.67185039 437.67036795 471.37851523]
# MSE of Bootstrap Mean Waiting Time: 2.7918
# 95% CI for Mean Waiting Time (bootstrap): [111.33, 117.86]
# Customers above 60.00 s: 3559, In percentage: 38.99%
#
# Run 81
# Mean, Median, Max and Variance of Waiting Time: 113.97 s, 13.36 s, 505.44 s, 22913.77 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.36258376 384.75620279 442.37481521 486.58348116]
# MSE of Bootstrap Mean Waiting Time: 2.4792
# 95% CI for Mean Waiting Time (bootstrap): [110.40, 117.06]
# Customers above 60.00 s: 3568, In percentage: 39.63%
#
# Run 82
# Mean, Median, Max and Variance of Waiting Time: 90.53 s, 13.23 s, 413.75 s, 14954.70 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.23091306 323.1207012  363.67465682 395.4704847 ]
# MSE of Bootstrap Mean Waiting Time: 1.5640
# 95% CI for Mean Waiting Time (bootstrap): [88.57, 93.20]
# Customers above 60.00 s: 3295, In percentage: 35.87%
#
# Run 83
# Mean, Median, Max and Variance of Waiting Time: 97.06 s, 13.51 s, 418.09 s, 17220.80 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.50721445 331.91128126 377.4586679  411.67639236]
# MSE of Bootstrap Mean Waiting Time: 1.2655
# 95% CI for Mean Waiting Time (bootstrap): [94.65, 99.49]
# Customers above 60.00 s: 3353, In percentage: 36.21%
#
# Run 84
# Mean, Median, Max and Variance of Waiting Time: 82.95 s, 13.51 s, 369.42 s, 12092.68 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.50522038 282.82084942 318.3852667  357.70869869]
# MSE of Bootstrap Mean Waiting Time: 1.4607
# 95% CI for Mean Waiting Time (bootstrap): [80.54, 84.88]
# Customers above 60.00 s: 3164, In percentage: 35.67%
#
# Run 85
# Mean, Median, Max and Variance of Waiting Time: 94.02 s, 14.18 s, 422.57 s, 16227.28 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.18202352 323.16319268 370.03791146 406.74145308]
# MSE of Bootstrap Mean Waiting Time: 1.9754
# 95% CI for Mean Waiting Time (bootstrap): [91.39, 96.76]
# Customers above 60.00 s: 3172, In percentage: 34.80%
#
# Run 86
# Mean, Median, Max and Variance of Waiting Time: 106.56 s, 13.44 s, 472.84 s, 20347.35 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.43778519 363.31875641 406.97426239 455.7127873 ]
# MSE of Bootstrap Mean Waiting Time: 2.7538
# 95% CI for Mean Waiting Time (bootstrap): [103.51, 109.56]
# Customers above 60.00 s: 3453, In percentage: 37.98%
#
# Run 87
# Mean, Median, Max and Variance of Waiting Time: 106.50 s, 14.60 s, 485.05 s, 20882.14 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.60346258 359.01766835 425.85270606 470.37731195]
# MSE of Bootstrap Mean Waiting Time: 1.6682
# 95% CI for Mean Waiting Time (bootstrap): [103.87, 109.02]
# Customers above 60.00 s: 3478, In percentage: 37.02%
#
# Run 88
# Mean, Median, Max and Variance of Waiting Time: 119.96 s, 14.42 s, 497.83 s, 24187.37 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.42158233 396.95853135 435.42976893 489.42876797]
# MSE of Bootstrap Mean Waiting Time: 3.0518
# 95% CI for Mean Waiting Time (bootstrap): [117.13, 123.43]
# Customers above 60.00 s: 3664, In percentage: 39.97%
#
# Run 89
# Mean, Median, Max and Variance of Waiting Time: 93.65 s, 13.94 s, 430.19 s, 15834.55 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.93961079 307.33500203 376.36806261 415.65885271]
# MSE of Bootstrap Mean Waiting Time: 1.8081
# 95% CI for Mean Waiting Time (bootstrap): [90.94, 95.97]
# Customers above 60.00 s: 3361, In percentage: 37.12%
#
# Run 90
# Mean, Median, Max and Variance of Waiting Time: 107.99 s, 13.92 s, 479.76 s, 20214.89 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.91855953 345.46668329 411.8450087  459.63946887]
# MSE of Bootstrap Mean Waiting Time: 1.9849
# 95% CI for Mean Waiting Time (bootstrap): [105.77, 110.84]
# Customers above 60.00 s: 3521, In percentage: 38.41%
#
# Run 91
# Mean, Median, Max and Variance of Waiting Time: 118.27 s, 14.56 s, 525.11 s, 25583.65 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.55516326 408.36987933 464.24112046 515.74750717]
# MSE of Bootstrap Mean Waiting Time: 3.0717
# 95% CI for Mean Waiting Time (bootstrap): [114.66, 121.39]
# Customers above 60.00 s: 3579, In percentage: 38.68%
#
# Run 92
# Mean, Median, Max and Variance of Waiting Time: 107.85 s, 13.92 s, 457.17 s, 20267.15 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.9185424  359.28640876 407.45136551 445.05404506]
# MSE of Bootstrap Mean Waiting Time: 2.3318
# 95% CI for Mean Waiting Time (bootstrap): [104.79, 110.81]
# Customers above 60.00 s: 3531, In percentage: 38.49%
#
# Run 93
# Mean, Median, Max and Variance of Waiting Time: 102.02 s, 13.18 s, 436.02 s, 18167.05 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.18131539 347.6603056  386.84414945 420.72346067]
# MSE of Bootstrap Mean Waiting Time: 2.1312
# 95% CI for Mean Waiting Time (bootstrap): [98.97, 104.30]
# Customers above 60.00 s: 3425, In percentage: 38.04%
#
# Run 94
# Mean, Median, Max and Variance of Waiting Time: 98.42 s, 13.05 s, 450.46 s, 17529.98 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.04675007 331.05652207 385.70356195 434.86214777]
# MSE of Bootstrap Mean Waiting Time: 2.1623
# 95% CI for Mean Waiting Time (bootstrap): [95.61, 100.98]
# Customers above 60.00 s: 3380, In percentage: 37.36%
#
# Run 95
# Mean, Median, Max and Variance of Waiting Time: 119.54 s, 14.29 s, 533.12 s, 25868.82 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.29471623 402.50125591 461.60757387 521.59213157]
# MSE of Bootstrap Mean Waiting Time: 3.2583
# 95% CI for Mean Waiting Time (bootstrap): [116.70, 123.21]
# Customers above 60.00 s: 3612, In percentage: 38.40%
#
# Run 96
# Mean, Median, Max and Variance of Waiting Time: 118.63 s, 14.97 s, 499.89 s, 24095.07 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.96515577 386.45233365 444.27883011 490.49705612]
# MSE of Bootstrap Mean Waiting Time: 2.4240
# 95% CI for Mean Waiting Time (bootstrap): [115.54, 121.92]
# Customers above 60.00 s: 3646, In percentage: 39.92%
#
# Run 97
# Mean, Median, Max and Variance of Waiting Time: 115.16 s, 13.84 s, 479.53 s, 23102.85 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.84387532 381.96531147 432.09148391 470.40678918]
# MSE of Bootstrap Mean Waiting Time: 2.5322
# 95% CI for Mean Waiting Time (bootstrap): [112.15, 118.33]
# Customers above 60.00 s: 3518, In percentage: 38.68%
#
# Run 98
# Mean, Median, Max and Variance of Waiting Time: 128.95 s, 14.34 s, 529.38 s, 27314.89 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 14.33741537 415.9594225  470.23065037 520.33422938]
# MSE of Bootstrap Mean Waiting Time: 2.8897
# 95% CI for Mean Waiting Time (bootstrap): [125.90, 132.84]
# Customers above 60.00 s: 3783, In percentage: 41.31%
#
# Run 99
# Mean, Median, Max and Variance of Waiting Time: 111.23 s, 13.64 s, 470.05 s, 21079.50 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 13.64216757 375.59547935 415.35335921 454.42318324]
# MSE of Bootstrap Mean Waiting Time: 2.0640
# 95% CI for Mean Waiting Time (bootstrap): [108.97, 113.83]
# Customers above 60.00 s: 3560, In percentage: 38.93%
#
# Run 100
# Mean, Median, Max and Variance of Waiting Time: 86.63 s, 12.80 s, 386.54 s, 13701.37 s
# Maximum Waiting Time 50th, 90th, 95th and 99th percentiles: [ 12.80029546 300.86901163 353.05089522 376.92539785]
# MSE of Bootstrap Mean Waiting Time: 1.4171
# 95% CI for Mean Waiting Time (bootstrap): [84.75, 89.25]
# Customers above 60.00 s: 3253, In percentage: 36.18%
# Elapsed time: 35.33 seconds

# %%
simulation = Simulation()
bootstrap_mse_convergence(simulation, stat_func=np.mean, max_bootstrap=10000, step=10)
# Out:
# Running single simulation for bootstrap convergence analysis...
